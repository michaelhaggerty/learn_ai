# %%
import json

data = {"location":{"address":{"addressLine1":"20 Adams Crossing Road","addressLine2":"","city":"East Nassau","country":"","county":null,"destinationLatitude":0,"destinationLongitude":0,"destinationState":null,"formattedAddress":null,"location":{"latitude":42.51177216,"longitude":-73.50881195},"originLatitude":0,"originLongitude":0,"postalCode":"12062","state":null},"allowsReservations":true,"coupons":[{"description":"2ND MONTH FREE W/1ST PAID","instructions":"2ND MONTH FREE W/1ST PAID"},{"description":"13th Month Free","instructions":"13th Month Free"},{"description":"10% MILITARY","instructions":"10% MILITARY"},{"description":"20% Employee Discount","instructions":"20% Employee Discount"},{"description":"1st Month Free","instructions":"1st Month Free"},{"description":"50% OFF 1ST 6 MONTHS","instructions":"50% OFF 1ST 6 MONTHS"},{"description":"10% SENIOR","instructions":"10% SENIOR"}],"facilityFeatures":[{"description":"","imageUrl":"http://www.webselfstorage.com/Image/6d3f4642-8c38-4fd1-9736-a3f72738e8ce"},{"description":"","imageUrl":"http://www.webselfstorage.com/Image/e9d11217-fb87-4dbb-b37c-c6084c8519b4"},{"description":"","imageUrl":"http://www.webselfstorage.com/Image/83a7f074-343e-4396-b79b-76a7da7fe091"},{"description":"","imageUrl":"http://www.webselfstorage.com/Image/7f31e954-e2c3-493c-bdb9-ea01da3c593c"}],"hoursOfOperation":{"gate":{"friday":{"close":"20:00:00","isOpen":true,"open":"08:00:00"},"monday":{"close":"20:00:00","isOpen":true,"open":"08:00:00"},"saturday":{"close":"20:00:00","isOpen":true,"open":"09:00:00"},"sunday":{"close":"20:00:00","isOpen":true,"open":"08:00:00"},"thursday":{"close":"20:00:00","isOpen":true,"open":"08:00:00"},"tuesday":{"close":"20:00:00","isOpen":true,"open":"08:00:00"},"wednesday":{"close":"20:00:00","isOpen":true,"open":"08:00:00"}},"office":{"friday":{"close":"20:00:00","isOpen":true,"open":"08:00:00"},"monday":{"close":"20:00:00","isOpen":true,"open":"08:00:00"},"saturday":{"close":"20:00:00","isOpen":true,"open":"09:00:00"},"sunday":{"close":"20:00:00","isOpen":true,"open":"08:00:00"},"thursday":{"close":"20:00:00","isOpen":true,"open":"08:00:00"},"tuesday":{"close":"20:00:00","isOpen":true,"open":"08:00:00"},"wednesday":{"close":"20:00:00","isOpen":true,"open":"08:00:00"}}},"locationFeatures":[{"description":"Wireless Internet Access"},{"description":"Online payments"},{"description":"24-Hour Access"}],"locationServices":[{"amount":1,"description":"Wireless Internet Access","locationServiceNumber":"7f0532b8-61c2-4432-b1f7-d927367e93df","taxable":"False"},{"amount":1,"description":"Online payments","locationServiceNumber":"6b2d1146-701e-4703-af35-8b4943cdd1f0","taxable":"False"},{"amount":1,"description":"24-Hour Access","locationServiceNumber":"8ee304f9-a131-40aa-bd55-0c68318b274c","taxable":"False"}],"name":"Speedway Storage","phone":"5187947820","reservationDates":["4/14/2024","4/15/2024","4/16/2024","4/17/2024","4/18/2024","4/19/2024","4/20/2024","4/21/2024","4/22/2024","4/23/2024","4/24/2024","4/25/2024","4/26/2024","4/27/2024","4/28/2024","4/29/2024","4/30/2024","5/1/2024","5/2/2024","5/3/2024","5/4/2024","5/5/2024","5/6/2024","5/7/2024","5/8/2024","5/9/2024","5/10/2024","5/11/2024","5/12/2024","5/13/2024","5/14/2024"],"reservationNotBelowPercentage":"0","reservationNotBelowTotalUnits":"0","reviewFee":0.0,"units":[{"bonusComments":"","cubicFootage":700,"orderGrouping":"000001Interior","squareFootage":100,"totalUnits":12,"unitFeature":null,"unitStorageGuide":null,"unitTypeImage":null,"height":7,"insuranceOptions":[{"description":"Flood Insurance $20,000","due":0,"insuranceId":"0647f793-d590-444e-9355-3c13ba69def9","monthlyRate":40.95,"percentage":0,"quantity":0,"selected":false,"tax":0.0000,"total":0},{"description":"Flood Insurance $1,000","due":0,"insuranceId":"d710a2f0-0cb4-449a-b6e3-40ce6d942802","monthlyRate":8.95,"percentage":0,"quantity":0,"selected":false,"tax":0.0000,"total":0},{"description":"Flood Insurance $5,000","due":0,"insuranceId":"664a7a30-1e04-4c39-99a2-4d5f0ad60cea","monthlyRate":11.95,"percentage":0,"quantity":0,"selected":false,"tax":0.0000,"total":0},{"description":"Flood Insurance $10,000","due":0,"insuranceId":"1fd544f9-d546-4555-b21c-f650424cff79","monthlyRate":21.95,"percentage":0,"quantity":0,"selected":false,"tax":0.0000,"total":0}],"isCampusStorage":false,"length":10,"monthly":70.00,"portable":{"isPortable":false,"onSiteOnly":false,"waiveDeliveryFee":false},"serviceCharges":null,"sizeDescriptionsField":["Interior 1st Floor No Climate Stair Swing No Electricity"],"unitId":"34d8a268-a8d2-46df-a8a8-5d5efff51469","rentableObjectId":"4cb8a262-0994-4ca4-8bb8-011ce2150135","unitSize":"10x10x7","vacantUnits":11,"width":10},{"bonusComments":"","cubicFootage":700,"orderGrouping":"000002Drive Up","squareFootage":100,"totalUnits":18,"unitFeature":null,"unitStorageGuide":null,"unitTypeImage":null,"height":7,"insuranceOptions":[{"description":"Flood Insurance $20,000","due":0,"insuranceId":"0647f793-d590-444e-9355-3c13ba69def9","monthlyRate":40.95,"percentage":0,"quantity":0,"selected":false,"tax":0.0000,"total":0},{"description":"Flood Insurance $1,000","due":0,"insuranceId":"d710a2f0-0cb4-449a-b6e3-40ce6d942802","monthlyRate":8.95,"percentage":0,"quantity":0,"selected":false,"tax":0.0000,"total":0},{"description":"Flood Insurance $5,000","due":0,"insuranceId":"664a7a30-1e04-4c39-99a2-4d5f0ad60cea","monthlyRate":11.95,"percentage":0,"quantity":0,"selected":false,"tax":0.0000,"total":0},{"description":"Flood Insurance $10,000","due":0,"insuranceId":"1fd544f9-d546-4555-b21c-f650424cff79","monthlyRate":21.95,"percentage":0,"quantity":0,"selected":false,"tax":0.0000,"total":0}],"isCampusStorage":false,"length":10,"monthly":70.00,"portable":{"isPortable":false,"onSiteOnly":false,"waiveDeliveryFee":false},"serviceCharges":null,"sizeDescriptionsField":["Drive Up 1st Floor Drivethrough"],"unitId":"ad545be6-7eef-401a-9ee9-d2505bd2eb06","rentableObjectId":"5ad3f123-61f1-446e-b7d7-2aae1600ae79","unitSize":"10x10x7","vacantUnits":16,"width":10},{"bonusComments":"","cubicFootage":1400,"orderGrouping":"000003Drive Up","squareFootage":200,"totalUnits":19,"unitFeature":null,"unitStorageGuide":null,"unitTypeImage":null,"height":7,"insuranceOptions":[{"description":"Flood Insurance $20,000","due":0,"insuranceId":"0647f793-d590-444e-9355-3c13ba69def9","monthlyRate":40.95,"percentage":0,"quantity":0,"selected":false,"tax":0.0000,"total":0},{"description":"Flood Insurance $1,000","due":0,"insuranceId":"d710a2f0-0cb4-449a-b6e3-40ce6d942802","monthlyRate":8.95,"percentage":0,"quantity":0,"selected":false,"tax":0.0000,"total":0},{"description":"Flood Insurance $5,000","due":0,"insuranceId":"664a7a30-1e04-4c39-99a2-4d5f0ad60cea","monthlyRate":11.95,"percentage":0,"quantity":0,"selected":false,"tax":0.0000,"total":0},{"description":"Flood Insurance $10,000","due":0,"insuranceId":"1fd544f9-d546-4555-b21c-f650424cff79","monthlyRate":21.95,"percentage":0,"quantity":0,"selected":false,"tax":0.0000,"total":0}],"isCampusStorage":false,"length":20,"monthly":110.00,"portable":{"isPortable":false,"onSiteOnly":false,"waiveDeliveryFee":false},"serviceCharges":null,"sizeDescriptionsField":["Drive Up 1st Floor No Climate Drivethrough Rollup No Electricity"],"unitId":"af3863ac-4d43-43f3-96d9-1f15cb5f9ecb","rentableObjectId":"988ec56c-2c92-4dcf-a97c-93c67c924715","unitSize":"10x20x7","vacantUnits":17,"width":10},{"bonusComments":"","cubicFootage":500,"orderGrouping":"000004Interior","squareFootage":50,"totalUnits":41,"unitFeature":null,"unitStorageGuide":null,"unitTypeImage":null,"height":10,"insuranceOptions":[{"description":"Flood Insurance $20,000","due":0,"insuranceId":"0647f793-d590-444e-9355-3c13ba69def9","monthlyRate":40.95,"percentage":0,"quantity":0,"selected":false,"tax":0.0000,"total":0},{"description":"Flood Insurance $1,000","due":0,"insuranceId":"d710a2f0-0cb4-449a-b6e3-40ce6d942802","monthlyRate":8.95,"percentage":0,"quantity":0,"selected":false,"tax":0.0000,"total":0},{"description":"Flood Insurance $5,000","due":0,"insuranceId":"664a7a30-1e04-4c39-99a2-4d5f0ad60cea","monthlyRate":11.95,"percentage":0,"quantity":0,"selected":false,"tax":0.0000,"total":0},{"description":"Flood Insurance $10,000","due":0,"insuranceId":"1fd544f9-d546-4555-b21c-f650424cff79","monthlyRate":21.95,"percentage":0,"quantity":0,"selected":false,"tax":0.0000,"total":0}],"isCampusStorage":false,"length":10,"monthly":40.00,"portable":{"isPortable":false,"onSiteOnly":true,"waiveDeliveryFee":false},"serviceCharges":null,"sizeDescriptionsField":["Interior 1st Floor Mezzanine Level No Climate Stair Swing Electricity"],"unitId":"8519860a-bb07-45c1-ba2a-fa322131ded7","rentableObjectId":"81e049c4-45f8-430f-a30b-af227added18","unitSize":"5x10x10","vacantUnits":39,"width":5}]},"success":true,"errorMessage":""}
formatted_json = json.dumps(data, indent=4)
print(formatted_json)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import json
# ...

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\python39\lib\site-packages)
# ...

# %%
KEY = "40d34272-e42d-46ca-a4ec-fca8b7bd6b5b"

# %%
import requests
import json

# URL and Authorization Key
url = "https://api.webselfstorage.com/v3/location/1038105"
headers = {
    "Authorization": "Bearer 40d34272-e42d-46ca-a4ec-fca8b7bd6b5b",  # Replace 'KEY' with your actual Bearer token
    "Accept": "application/json"
}

# Make the GET request
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse JSON data from the response
    data = response.json()
    # Pretty print the JSON data
    print(json.dumps(data, indent=4))
else:
    print(f"Failed to retrieve data: {response.status_code}")
# Out:
# {
#     "location": {
#         "address": {
#             "addressLine1": "20 Adams Crossing Road",
#             "addressLine2": "",
#             "city": "East Nassau",
#             "country": "",
#             "county": null,
#             "destinationLatitude": 0,
#             "destinationLongitude": 0,
#             "destinationState": null,
#             "formattedAddress": null,
#             "location": {
#                 "latitude": 42.51177216,
#                 "longitude": -73.50881195
#             },
#             "originLatitude": 0,
#             "originLongitude": 0,
#             "postalCode": "12062",
#             "state": null
#         },
#         "allowsReservations": true,
#         "coupons": [
#             {
#                 "description": "2ND MONTH FREE W/1ST PAID",
#                 "instructions": "2ND MONTH FREE W/1ST PAID"
#             },
#             {
#                 "description": "13th Month Free",
# ...

# %%
data["location"]["units"]
# Out:
# [{'bonusComments': '',
#   'cubicFootage': 700,
#   'orderGrouping': '000001Interior',
#   'squareFootage': 100,
#   'totalUnits': 12,
#   'unitFeature': None,
#   'unitStorageGuide': None,
#   'unitTypeImage': None,
#   'height': 7,
#   'insuranceOptions': [{'description': 'Flood Insurance $20,000',
#     'due': 0,
#     'insuranceId': '0647f793-d590-444e-9355-3c13ba69def9',
#     'monthlyRate': 40.95,
#     'percentage': 0,
#     'quantity': 0,
#     'selected': False,
#     'tax': 0.0,
#     'total': 0},
#    {'description': 'Flood Insurance $1,000',
#     'due': 0,
#     'insuranceId': 'd710a2f0-0cb4-449a-b6e3-40ce6d942802',
#     'monthlyRate': 8.95,
#     'percentage': 0,
#     'quantity': 0,
#     'selected': False,
#     'tax': 0.0,
#     'total': 0},
#    {'description': 'Flood Insurance $5,000',
#     'due': 0,
#     'insuranceId': '664a7a30-1e04-4c39-99a2-4d5f0ad60cea',
#     'monthlyRate': 11.95,
#     'percentage': 0,
#     'quantity': 0,
#     'selected': False,
# ...

# %%
# Access the 'units' key which is a list of units
units = data['location']['units']

# Create a dictionary with unit size and vacant units
unit_size_vacant = [
    {'unitSize': unit['unitSize'], 'vacantUnits': unit['vacantUnits']}
    for unit in units
]

# Print the dictionary
print(unit_size_vacant)
# Out:
# [{'unitSize': '10x10x7', 'vacantUnits': 11}, {'unitSize': '10x10x7', 'vacantUnits': 16}, {'unitSize': '10x20x7', 'vacantUnits': 17}, {'unitSize': '5x10x10', 'vacantUnits': 39}]

# %%
import requests
import json

# URL and Authorization Key
url = "https://api.webselfstorage.com/v3/locations"
headers = {
    "Authorization": "Bearer 40d34272-e42d-46ca-a4ec-fca8b7bd6b5b",  # Replace 'KEY' with your actual Bearer token
    "Accept": "application/json"
}

# Make the GET request
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Parse JSON data from the response
    data = response.json()
    # Pretty print the JSON data
    print(json.dumps(data, indent=4))
else:
    print(f"Failed to retrieve data: {response.status_code}")
# Out:
# {
#     "entities": [
#         1038105
#     ],
#     "success": true,
#     "errorMessage": ""
# }

# %%
data["entities"][0]
# Out:
# 1038105

# %%
import json

# JSON data as a string
json_data = '{"name": "John", "age": 30, "city": "New York", "skills": {"python": true, "java": false}}'

# Convert JSON string to Python dictionary
data = json.loads(json_data)

# %%
data
# Out:
# {'name': 'John',
#  'age': 30,
#  'city': 'New York',
#  'skills': {'python': True, 'java': False}}

# %%
data["age"]
# Out:
# 30
